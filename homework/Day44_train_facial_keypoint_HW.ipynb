# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import imgaug.augmenters as iaa
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive/GEODAC/1st-DL-CVMarathon/Day044'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑
# Out:
# `%tensorflow_version` only switches the major version: `1.x` or `2.x`.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.0
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/GEODAC/1st-DL-CVMarathon/Day044

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 如果要使用 kaggle API 下載資料的話，請用以下程式碼
os.environ['KAGGLE_USERNAME'] = 'jianjhihlai' # 請按照 Day42 簡報內容，獲取 kaggle api 需要用到的 username
os.environ['KAGGLE_KEY'] = '76387c48b063639ca218e0ea53580e51' # 請按照 Day42 簡報獲取 kaggle api 需要用到的 key
# !kaggle competitions download -c facial-keypoints-detection
# !unzip test.zip
# !unzip training.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# training.zip: Skipping, found more recently modified local copy (use --force to force download)
# test.zip: Skipping, found more recently modified local copy (use --force to force download)
# IdLookupTable.csv: Skipping, found more recently modified local copy (use --force to force download)
# SampleSubmission.csv: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  test.zip
# replace test.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# Archive:  training.zip
# replace training.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 16s 9ms/step - loss: 0.0080 - val_loss: 0.0024
#
# Epoch 00001: val_loss improved from inf to 0.00239, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 282us/step - loss: 0.0021 - val_loss: 0.0020
#
# Epoch 00002: val_loss improved from 0.00239 to 0.00197, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00197 to 0.00185, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00185
# Epoch 5/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00185 to 0.00182, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 0.0011 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00182 to 0.00170, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 9.3282e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00170 to 0.00163, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 7.9635e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00163 to 0.00158, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 7.2001e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00158 to 0.00135, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 253us/step - loss: 6.3451e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00135 to 0.00129, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 253us/step - loss: 6.1726e-04 - val_loss: 0.0013
#
# Epoch 00011: val_loss improved from 0.00129 to 0.00128, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 5.5271e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00128 to 0.00114, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 5.0997e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00114 to 0.00108, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 4.7148e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss improved from 0.00108 to 0.00108, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 4.5350e-04 - val_loss: 9.9180e-04
#
# Epoch 00015: val_loss improved from 0.00108 to 0.00099, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 4.2653e-04 - val_loss: 9.7467e-04
#
# Epoch 00016: val_loss improved from 0.00099 to 0.00097, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 261us/step - loss: 4.0631e-04 - val_loss: 9.2659e-04
#
# Epoch 00017: val_loss improved from 0.00097 to 0.00093, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 3.8489e-04 - val_loss: 9.3457e-04
#
# Epoch 00018: val_loss did not improve from 0.00093
# Epoch 19/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 3.8072e-04 - val_loss: 9.0358e-04
#
# Epoch 00019: val_loss improved from 0.00093 to 0.00090, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 3.6118e-04 - val_loss: 9.2394e-04
#
# Epoch 00020: val_loss did not improve from 0.00090
# Epoch 21/150
# 1712/1712 [==============================] - 0s 242us/step - loss: 3.6141e-04 - val_loss: 8.9952e-04
#
# Epoch 00021: val_loss improved from 0.00090 to 0.00090, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 0s 262us/step - loss: 3.3572e-04 - val_loss: 8.8915e-04
#
# Epoch 00022: val_loss improved from 0.00090 to 0.00089, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 0s 255us/step - loss: 3.1742e-04 - val_loss: 8.7159e-04
#
# Epoch 00023: val_loss improved from 0.00089 to 0.00087, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 0s 252us/step - loss: 3.1730e-04 - val_loss: 8.7280e-04
#
# Epoch 00024: val_loss did not improve from 0.00087
# Epoch 25/150
# 1712/1712 [==============================] - 0s 261us/step - loss: 3.1359e-04 - val_loss: 8.8273e-04
#
# Epoch 00025: val_loss did not improve from 0.00087
# Epoch 26/150
# 1712/1712 [==============================] - 0s 251us/step - loss: 3.0081e-04 - val_loss: 8.5451e-04
#
# Epoch 00026: val_loss improved from 0.00087 to 0.00085, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 0s 264us/step - loss: 2.9682e-04 - val_loss: 8.0868e-04
#
# Epoch 00027: val_loss improved from 0.00085 to 0.00081, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 2.9181e-04 - val_loss: 8.7460e-04
#
# Epoch 00028: val_loss did not improve from 0.00081
# Epoch 29/150
# 1712/1712 [==============================] - 0s 257us/step - loss: 2.8393e-04 - val_loss: 8.4760e-04
#
# Epoch 00029: val_loss did not improve from 0.00081
# Epoch 30/150
# 1712/1712 [==============================] - 0s 257us/step - loss: 2.7771e-04 - val_loss: 8.3035e-04
#
# Epoch 00030: val_loss did not improve from 0.00081
# Epoch 31/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 2.7213e-04 - val_loss: 8.5966e-04
#
# Epoch 00031: val_loss did not improve from 0.00081
# Epoch 32/150
# 1712/1712 [==============================] - 0s 259us/step - loss: 2.6196e-04 - val_loss: 8.6521e-04
#
# Epoch 00032: val_loss did not improve from 0.00081
# Epoch 33/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 2.6271e-04 - val_loss: 8.2136e-04
#
# Epoch 00033: val_loss did not improve from 0.00081
# Epoch 34/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 2.5170e-04 - val_loss: 8.2857e-04
#
# Epoch 00034: val_loss did not improve from 0.00081
# Epoch 35/150
# 1712/1712 [==============================] - 0s 258us/step - loss: 2.4272e-04 - val_loss: 7.9832e-04
#
# Epoch 00035: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 0s 262us/step - loss: 2.4282e-04 - val_loss: 8.1108e-04
#
# Epoch 00036: val_loss did not improve from 0.00080
# Epoch 37/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 2.3265e-04 - val_loss: 8.0289e-04
#
# Epoch 00037: val_loss did not improve from 0.00080
# Epoch 38/150
# 1712/1712 [==============================] - 0s 261us/step - loss: 2.3107e-04 - val_loss: 8.5842e-04
#
# Epoch 00038: val_loss did not improve from 0.00080
# Epoch 39/150
# 1712/1712 [==============================] - 0s 260us/step - loss: 2.3402e-04 - val_loss: 7.7992e-04
#
# Epoch 00039: val_loss improved from 0.00080 to 0.00078, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 0s 258us/step - loss: 2.2920e-04 - val_loss: 7.8519e-04
#
# Epoch 00040: val_loss did not improve from 0.00078
# Epoch 41/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 2.2489e-04 - val_loss: 7.8180e-04
#
# Epoch 00041: val_loss did not improve from 0.00078
# Epoch 42/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 2.3088e-04 - val_loss: 8.5936e-04
#
# Epoch 00042: val_loss did not improve from 0.00078
# Epoch 43/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 2.2063e-04 - val_loss: 8.0874e-04
#
# Epoch 00043: val_loss did not improve from 0.00078
# Epoch 44/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 2.1231e-04 - val_loss: 7.8700e-04
#
# Epoch 00044: val_loss did not improve from 0.00078
# Epoch 45/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 2.0661e-04 - val_loss: 8.0461e-04
#
# Epoch 00045: val_loss did not improve from 0.00078
# Epoch 46/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 2.1020e-04 - val_loss: 8.1682e-04
#
# Epoch 00046: val_loss did not improve from 0.00078
# Epoch 47/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 2.0135e-04 - val_loss: 8.2500e-04
#
# Epoch 00047: val_loss did not improve from 0.00078
# Epoch 48/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 2.0365e-04 - val_loss: 7.8936e-04
#
# Epoch 00048: val_loss did not improve from 0.00078
# Epoch 49/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 1.9854e-04 - val_loss: 7.7877e-04
#
# Epoch 00049: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 50/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.9373e-04 - val_loss: 7.9993e-04
#
# Epoch 00050: val_loss did not improve from 0.00078
# Epoch 51/150
# 1712/1712 [==============================] - 0s 259us/step - loss: 1.9409e-04 - val_loss: 8.0352e-04
#
# Epoch 00051: val_loss did not improve from 0.00078
# Epoch 52/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 1.9289e-04 - val_loss: 7.8238e-04
#
# Epoch 00052: val_loss did not improve from 0.00078
# Epoch 53/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 1.8990e-04 - val_loss: 7.9543e-04
#
# Epoch 00053: val_loss did not improve from 0.00078
# Epoch 54/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 1.8960e-04 - val_loss: 7.7631e-04
#
# Epoch 00054: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 55/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 1.8385e-04 - val_loss: 7.5801e-04
#
# Epoch 00055: val_loss improved from 0.00078 to 0.00076, saving model to best_weights.h5
# Epoch 56/150
# 1712/1712 [==============================] - 0s 258us/step - loss: 1.8454e-04 - val_loss: 7.6411e-04
#
# Epoch 00056: val_loss did not improve from 0.00076
# Epoch 57/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 1.7915e-04 - val_loss: 7.9123e-04
#
# Epoch 00057: val_loss did not improve from 0.00076
# Epoch 58/150
# 1712/1712 [==============================] - 0s 263us/step - loss: 1.8067e-04 - val_loss: 7.5294e-04
#
# Epoch 00058: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 59/150
# 1712/1712 [==============================] - 0s 251us/step - loss: 1.7978e-04 - val_loss: 8.1795e-04
#
# Epoch 00059: val_loss did not improve from 0.00075
# Epoch 60/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.7973e-04 - val_loss: 8.0117e-04
#
# Epoch 00060: val_loss did not improve from 0.00075
# Epoch 61/150
# 1712/1712 [==============================] - 0s 258us/step - loss: 1.7876e-04 - val_loss: 8.0180e-04
#
# Epoch 00061: val_loss did not improve from 0.00075
# Epoch 62/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 1.7141e-04 - val_loss: 8.1270e-04
#
# Epoch 00062: val_loss did not improve from 0.00075
# Epoch 63/150
# 1712/1712 [==============================] - 0s 257us/step - loss: 1.6651e-04 - val_loss: 7.8036e-04
#
# Epoch 00063: val_loss did not improve from 0.00075
# Epoch 64/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 1.6333e-04 - val_loss: 8.1002e-04
#
# Epoch 00064: val_loss did not improve from 0.00075
# Epoch 65/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 1.6970e-04 - val_loss: 7.7662e-04
#
# Epoch 00065: val_loss did not improve from 0.00075
# Epoch 66/150
# 1712/1712 [==============================] - 0s 239us/step - loss: 1.6679e-04 - val_loss: 7.4511e-04
#
# Epoch 00066: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 67/150
# 1712/1712 [==============================] - 0s 251us/step - loss: 1.6364e-04 - val_loss: 7.8633e-04
#
# Epoch 00067: val_loss did not improve from 0.00075
# Epoch 68/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 1.6157e-04 - val_loss: 7.9834e-04
#
# Epoch 00068: val_loss did not improve from 0.00075
# Epoch 69/150
# 1712/1712 [==============================] - 0s 253us/step - loss: 1.5921e-04 - val_loss: 7.5929e-04
#
# Epoch 00069: val_loss did not improve from 0.00075
# Epoch 70/150
# 1712/1712 [==============================] - 0s 263us/step - loss: 1.5685e-04 - val_loss: 7.8118e-04
#
# Epoch 00070: val_loss did not improve from 0.00075
# Epoch 71/150
# 1712/1712 [==============================] - 0s 255us/step - loss: 1.5646e-04 - val_loss: 8.2329e-04
#
# Epoch 00071: val_loss did not improve from 0.00075
# Epoch 72/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 1.5739e-04 - val_loss: 8.1898e-04
#
# Epoch 00072: val_loss did not improve from 0.00075
# Epoch 73/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 1.5402e-04 - val_loss: 7.7463e-04
#
# Epoch 00073: val_loss did not improve from 0.00075
# Epoch 74/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.5782e-04 - val_loss: 7.8931e-04
#
# Epoch 00074: val_loss did not improve from 0.00075
# Epoch 75/150
# 1712/1712 [==============================] - 0s 255us/step - loss: 1.5164e-04 - val_loss: 8.1654e-04
#
# Epoch 00075: val_loss did not improve from 0.00075
# Epoch 76/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 1.5002e-04 - val_loss: 7.8676e-04
#
# Epoch 00076: val_loss did not improve from 0.00075
# Epoch 77/150
# 1712/1712 [==============================] - 0s 255us/step - loss: 1.5288e-04 - val_loss: 7.9438e-04
#
# Epoch 00077: val_loss did not improve from 0.00075
# Epoch 78/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.5070e-04 - val_loss: 8.0592e-04
#
# Epoch 00078: val_loss did not improve from 0.00075
# Epoch 79/150
# 1712/1712 [==============================] - 0s 261us/step - loss: 1.5233e-04 - val_loss: 8.0168e-04
#
# Epoch 00079: val_loss did not improve from 0.00075
# Epoch 80/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 1.4433e-04 - val_loss: 7.7578e-04
#
# Epoch 00080: val_loss did not improve from 0.00075
# Epoch 81/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 1.3906e-04 - val_loss: 7.6649e-04
#
# Epoch 00081: val_loss did not improve from 0.00075
# Epoch 82/150
# 1712/1712 [==============================] - 0s 264us/step - loss: 1.3784e-04 - val_loss: 7.8213e-04
#
# Epoch 00082: val_loss did not improve from 0.00075
# Epoch 83/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 1.3547e-04 - val_loss: 7.7381e-04
#
# Epoch 00083: val_loss did not improve from 0.00075
# Epoch 84/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 1.3669e-04 - val_loss: 7.6274e-04
#
# Epoch 00084: val_loss did not improve from 0.00075
# Epoch 85/150
# 1712/1712 [==============================] - 0s 264us/step - loss: 1.3546e-04 - val_loss: 7.9350e-04
#
# Epoch 00085: val_loss did not improve from 0.00075
# Epoch 86/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 1.3760e-04 - val_loss: 7.5484e-04
#
# Epoch 00086: val_loss did not improve from 0.00075
# Epoch 87/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 1.3458e-04 - val_loss: 7.8181e-04
#
# Epoch 00087: val_loss did not improve from 0.00075
# Epoch 88/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 1.3500e-04 - val_loss: 7.4734e-04
#
# Epoch 00088: val_loss did not improve from 0.00075
# Epoch 89/150
# 1712/1712 [==============================] - 0s 255us/step - loss: 1.3215e-04 - val_loss: 7.8325e-04
#
# Epoch 00089: val_loss did not improve from 0.00075
# Epoch 90/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.3346e-04 - val_loss: 7.8920e-04
#
# Epoch 00090: val_loss did not improve from 0.00075
# Epoch 91/150
# 1712/1712 [==============================] - 0s 255us/step - loss: 1.3372e-04 - val_loss: 7.6611e-04
#
# Epoch 00091: val_loss did not improve from 0.00075
# Epoch 92/150
# 1712/1712 [==============================] - 0s 253us/step - loss: 1.3311e-04 - val_loss: 7.5649e-04
#
# Epoch 00092: val_loss did not improve from 0.00075
# Epoch 93/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 1.3117e-04 - val_loss: 7.5637e-04
#
# Epoch 00093: val_loss did not improve from 0.00075
# Epoch 94/150
# 1712/1712 [==============================] - 0s 251us/step - loss: 1.2467e-04 - val_loss: 8.0296e-04
#
# Epoch 00094: val_loss did not improve from 0.00075
# Epoch 95/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 1.2456e-04 - val_loss: 7.9259e-04
#
# Epoch 00095: val_loss did not improve from 0.00075
# Epoch 96/150
# 1712/1712 [==============================] - 0s 237us/step - loss: 1.2365e-04 - val_loss: 7.9893e-04
#
# Epoch 00096: val_loss did not improve from 0.00075
# Epoch 97/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 1.2650e-04 - val_loss: 7.9038e-04
#
# Epoch 00097: val_loss did not improve from 0.00075
# Epoch 98/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 1.2540e-04 - val_loss: 7.9631e-04
#
# Epoch 00098: val_loss did not improve from 0.00075
# Epoch 99/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 1.2012e-04 - val_loss: 7.7595e-04
#
# Epoch 00099: val_loss did not improve from 0.00075
# Epoch 100/150
# 1712/1712 [==============================] - 0s 257us/step - loss: 1.2329e-04 - val_loss: 7.4705e-04
#
# Epoch 00100: val_loss did not improve from 0.00075
# Epoch 101/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 1.2018e-04 - val_loss: 7.8660e-04
#
# Epoch 00101: val_loss did not improve from 0.00075
# Epoch 102/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 1.2290e-04 - val_loss: 7.6260e-04
#
# Epoch 00102: val_loss did not improve from 0.00075
# Epoch 103/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 1.2462e-04 - val_loss: 7.6659e-04
#
# Epoch 00103: val_loss did not improve from 0.00075
# Epoch 104/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 1.1963e-04 - val_loss: 7.9250e-04
#
# Epoch 00104: val_loss did not improve from 0.00075
# Epoch 105/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 1.1724e-04 - val_loss: 8.0070e-04
#
# Epoch 00105: val_loss did not improve from 0.00075
# Epoch 106/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 1.1807e-04 - val_loss: 7.7084e-04
#
# Epoch 00106: val_loss did not improve from 0.00075
# Epoch 107/150
# 1712/1712 [==============================] - 0s 242us/step - loss: 1.1902e-04 - val_loss: 8.0547e-04
#
# Epoch 00107: val_loss did not improve from 0.00075
# Epoch 108/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 1.1553e-04 - val_loss: 7.6281e-04
#
# Epoch 00108: val_loss did not improve from 0.00075
# Epoch 109/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 1.1993e-04 - val_loss: 7.4672e-04
#
# Epoch 00109: val_loss did not improve from 0.00075
# Epoch 110/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 1.2251e-04 - val_loss: 7.8060e-04
#
# Epoch 00110: val_loss did not improve from 0.00075
# Epoch 111/150
# 1712/1712 [==============================] - 0s 243us/step - loss: 1.1726e-04 - val_loss: 7.8963e-04
#
# Epoch 00111: val_loss did not improve from 0.00075
# Epoch 112/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.1721e-04 - val_loss: 8.0715e-04
#
# Epoch 00112: val_loss did not improve from 0.00075
# Epoch 113/150
# 1712/1712 [==============================] - 0s 257us/step - loss: 1.1271e-04 - val_loss: 8.1455e-04
#
# Epoch 00113: val_loss did not improve from 0.00075
# Epoch 114/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.1017e-04 - val_loss: 7.7968e-04
#
# Epoch 00114: val_loss did not improve from 0.00075
# Epoch 115/150
# 1712/1712 [==============================] - 0s 262us/step - loss: 1.0920e-04 - val_loss: 8.1408e-04
#
# Epoch 00115: val_loss did not improve from 0.00075
# Epoch 116/150
# 1712/1712 [==============================] - 0s 255us/step - loss: 1.0798e-04 - val_loss: 8.0214e-04
#
# Epoch 00116: val_loss did not improve from 0.00075
# Epoch 117/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.0810e-04 - val_loss: 8.1615e-04
#
# Epoch 00117: val_loss did not improve from 0.00075
# Epoch 118/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 1.0792e-04 - val_loss: 8.4472e-04
#
# Epoch 00118: val_loss did not improve from 0.00075
# Epoch 119/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 1.0834e-04 - val_loss: 8.2084e-04
#
# Epoch 00119: val_loss did not improve from 0.00075
# Epoch 120/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 1.0850e-04 - val_loss: 8.1210e-04
#
# Epoch 00120: val_loss did not improve from 0.00075
# Epoch 121/150
# 1712/1712 [==============================] - 0s 242us/step - loss: 1.0782e-04 - val_loss: 7.8644e-04
#
# Epoch 00121: val_loss did not improve from 0.00075
# Epoch 122/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 1.0711e-04 - val_loss: 7.9303e-04
#
# Epoch 00122: val_loss did not improve from 0.00075
# Epoch 123/150
# 1712/1712 [==============================] - 0s 244us/step - loss: 1.0712e-04 - val_loss: 8.0625e-04
#
# Epoch 00123: val_loss did not improve from 0.00075
# Epoch 124/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 1.0208e-04 - val_loss: 7.9086e-04
#
# Epoch 00124: val_loss did not improve from 0.00075
# Epoch 125/150
# 1712/1712 [==============================] - 0s 256us/step - loss: 1.0326e-04 - val_loss: 8.0367e-04
#
# Epoch 00125: val_loss did not improve from 0.00075
# Epoch 126/150
# 1712/1712 [==============================] - 0s 256us/step - loss: 1.0102e-04 - val_loss: 7.9823e-04
#
# Epoch 00126: val_loss did not improve from 0.00075
# Epoch 127/150
# 1712/1712 [==============================] - 0s 255us/step - loss: 1.0561e-04 - val_loss: 7.8261e-04
#
# Epoch 00127: val_loss did not improve from 0.00075
# Epoch 128/150
# 1712/1712 [==============================] - 0s 254us/step - loss: 1.0576e-04 - val_loss: 7.8193e-04
#
# Epoch 00128: val_loss did not improve from 0.00075
# Epoch 129/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 1.0288e-04 - val_loss: 8.2290e-04
#
# Epoch 00129: val_loss did not improve from 0.00075
# Epoch 130/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 1.0062e-04 - val_loss: 7.8575e-04
#
# Epoch 00130: val_loss did not improve from 0.00075
# Epoch 131/150
# 1712/1712 [==============================] - 0s 252us/step - loss: 9.9170e-05 - val_loss: 8.0827e-04
#
# Epoch 00131: val_loss did not improve from 0.00075
# Epoch 132/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 9.7079e-05 - val_loss: 7.8209e-04
#
# Epoch 00132: val_loss did not improve from 0.00075
# Epoch 133/150
# 1712/1712 [==============================] - 0s 252us/step - loss: 9.9670e-05 - val_loss: 7.8769e-04
#
# Epoch 00133: val_loss did not improve from 0.00075
# Epoch 134/150
# 1712/1712 [==============================] - 0s 253us/step - loss: 9.6648e-05 - val_loss: 7.7419e-04
#
# Epoch 00134: val_loss did not improve from 0.00075
# Epoch 135/150
# 1712/1712 [==============================] - 0s 253us/step - loss: 9.7185e-05 - val_loss: 7.9054e-04
#
# Epoch 00135: val_loss did not improve from 0.00075
# Epoch 136/150
# 1712/1712 [==============================] - 0s 249us/step - loss: 9.9035e-05 - val_loss: 8.1598e-04
#
# Epoch 00136: val_loss did not improve from 0.00075
# Epoch 137/150
# 1712/1712 [==============================] - 0s 247us/step - loss: 9.9762e-05 - val_loss: 7.4992e-04
#
# Epoch 00137: val_loss did not improve from 0.00075
# Epoch 138/150
# 1712/1712 [==============================] - 0s 257us/step - loss: 9.8716e-05 - val_loss: 8.1355e-04
#
# Epoch 00138: val_loss did not improve from 0.00075
# Epoch 139/150
# 1712/1712 [==============================] - 0s 258us/step - loss: 9.3366e-05 - val_loss: 7.9532e-04
#
# Epoch 00139: val_loss did not improve from 0.00075
# Epoch 140/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 9.6116e-05 - val_loss: 7.9483e-04
#
# Epoch 00140: val_loss did not improve from 0.00075
# Epoch 141/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 9.4346e-05 - val_loss: 7.9209e-04
#
# Epoch 00141: val_loss did not improve from 0.00075
# Epoch 142/150
# 1712/1712 [==============================] - 0s 253us/step - loss: 9.3340e-05 - val_loss: 8.0104e-04
#
# Epoch 00142: val_loss did not improve from 0.00075
# Epoch 143/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 9.3092e-05 - val_loss: 7.7940e-04
#
# Epoch 00143: val_loss did not improve from 0.00075
# Epoch 144/150
# 1712/1712 [==============================] - 0s 252us/step - loss: 9.2945e-05 - val_loss: 8.1693e-04
#
# Epoch 00144: val_loss did not improve from 0.00075
# Epoch 145/150
# 1712/1712 [==============================] - 0s 251us/step - loss: 9.2355e-05 - val_loss: 8.0930e-04
#
# Epoch 00145: val_loss did not improve from 0.00075
# Epoch 146/150
# 1712/1712 [==============================] - 0s 251us/step - loss: 9.4098e-05 - val_loss: 7.6515e-04
#
# Epoch 00146: val_loss did not improve from 0.00075
# Epoch 147/150
# 1712/1712 [==============================] - 0s 252us/step - loss: 9.1645e-05 - val_loss: 7.8480e-04
#
# Epoch 00147: val_loss did not improve from 0.00075
# Epoch 148/150
# 1712/1712 [==============================] - 0s 245us/step - loss: 9.3573e-05 - val_loss: 8.0062e-04
#
# Epoch 00148: val_loss did not improve from 0.00075
# Epoch 149/150
# 1712/1712 [==============================] - 0s 248us/step - loss: 9.2407e-05 - val_loss: 8.0384e-04
#
# Epoch 00149: val_loss did not improve from 0.00075
# Epoch 150/150
# 1712/1712 [==============================] - 0s 250us/step - loss: 9.1605e-05 - val_loss: 8.1337e-04
#
# Epoch 00150: val_loss did not improve from 0.00075

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
def keypoint_pairing(sample_points):
    points = []
    for k in sample_points:
        coors = []
        for i in range(0, sample_points.shape[1], 2):
            coors.append(((k[i]+ 0.5)*96, (k[i+1]+ 0.5)*96))
        points.append(coors)
    return points

points = keypoint_pairing(points_train)

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5)
])
imgs_train_aug, points_train_aug = seq(images=imgs_train, keypoints=points)
points_train_aug = np.asarray(points_train_aug)/96 - 0.5
print("圖像資料:", imgs_train_aug.shape, "\n關鍵點資料:", points_train_aug.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 15, 2)

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights_aug.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model_aug = model_with_augment.fit(imgs_train_aug.reshape(-1, 96, 96, 1), 
                       points_train_aug.reshape(-1, 30), 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model_with_augment.save_weights('weights_aug.h5')
# save the model
model_with_augment.save('model_aug.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 16s 9ms/step - loss: 0.0233 - val_loss: 0.0202
#
# Epoch 00001: val_loss improved from inf to 0.02024, saving model to best_weights_aug.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 0.0194 - val_loss: 0.0194
#
# Epoch 00002: val_loss improved from 0.02024 to 0.01937, saving model to best_weights_aug.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 0.0189 - val_loss: 0.0193
#
# Epoch 00003: val_loss improved from 0.01937 to 0.01935, saving model to best_weights_aug.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 0.0185 - val_loss: 0.0200
#
# Epoch 00004: val_loss did not improve from 0.01935
# Epoch 5/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 0.0162 - val_loss: 0.0279
#
# Epoch 00005: val_loss did not improve from 0.01935
# Epoch 6/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 0.0126 - val_loss: 0.0250
#
# Epoch 00006: val_loss did not improve from 0.01935
# Epoch 7/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 0.0090 - val_loss: 0.0262
#
# Epoch 00007: val_loss did not improve from 0.01935
# Epoch 8/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 0.0066 - val_loss: 0.0267
#
# Epoch 00008: val_loss did not improve from 0.01935
# Epoch 9/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 0.0046 - val_loss: 0.0278
#
# Epoch 00009: val_loss did not improve from 0.01935
# Epoch 10/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 0.0034 - val_loss: 0.0262
#
# Epoch 00010: val_loss did not improve from 0.01935
# Epoch 11/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 0.0026 - val_loss: 0.0268
#
# Epoch 00011: val_loss did not improve from 0.01935
# Epoch 12/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 0.0020 - val_loss: 0.0284
#
# Epoch 00012: val_loss did not improve from 0.01935
# Epoch 13/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 0.0015 - val_loss: 0.0265
#
# Epoch 00013: val_loss did not improve from 0.01935
# Epoch 14/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 0.0012 - val_loss: 0.0266
#
# Epoch 00014: val_loss did not improve from 0.01935
# Epoch 15/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 0.0011 - val_loss: 0.0265
#
# Epoch 00015: val_loss did not improve from 0.01935
# Epoch 16/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 9.5910e-04 - val_loss: 0.0270
#
# Epoch 00016: val_loss did not improve from 0.01935
# Epoch 17/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 8.8103e-04 - val_loss: 0.0274
#
# Epoch 00017: val_loss did not improve from 0.01935
# Epoch 18/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 8.3586e-04 - val_loss: 0.0272
#
# Epoch 00018: val_loss did not improve from 0.01935
# Epoch 19/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 8.0907e-04 - val_loss: 0.0271
#
# Epoch 00019: val_loss did not improve from 0.01935
# Epoch 20/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 7.7017e-04 - val_loss: 0.0272
#
# Epoch 00020: val_loss did not improve from 0.01935
# Epoch 21/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 7.1124e-04 - val_loss: 0.0265
#
# Epoch 00021: val_loss did not improve from 0.01935
# Epoch 22/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 6.7409e-04 - val_loss: 0.0270
#
# Epoch 00022: val_loss did not improve from 0.01935
# Epoch 23/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 6.6265e-04 - val_loss: 0.0257
#
# Epoch 00023: val_loss did not improve from 0.01935
# Epoch 24/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 6.3181e-04 - val_loss: 0.0263
#
# Epoch 00024: val_loss did not improve from 0.01935
# Epoch 25/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 6.0325e-04 - val_loss: 0.0269
#
# Epoch 00025: val_loss did not improve from 0.01935
# Epoch 26/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 5.8912e-04 - val_loss: 0.0272
#
# Epoch 00026: val_loss did not improve from 0.01935
# Epoch 27/150
# 1712/1712 [==============================] - 0s 238us/step - loss: 5.7304e-04 - val_loss: 0.0262
#
# Epoch 00027: val_loss did not improve from 0.01935
# Epoch 28/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 5.5493e-04 - val_loss: 0.0272
#
# Epoch 00028: val_loss did not improve from 0.01935
# Epoch 29/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 5.3706e-04 - val_loss: 0.0270
#
# Epoch 00029: val_loss did not improve from 0.01935
# Epoch 30/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 5.1893e-04 - val_loss: 0.0264
#
# Epoch 00030: val_loss did not improve from 0.01935
# Epoch 31/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 4.9835e-04 - val_loss: 0.0270
#
# Epoch 00031: val_loss did not improve from 0.01935
# Epoch 32/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 4.9180e-04 - val_loss: 0.0266
#
# Epoch 00032: val_loss did not improve from 0.01935
# Epoch 33/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 4.8082e-04 - val_loss: 0.0268
#
# Epoch 00033: val_loss did not improve from 0.01935
# Epoch 34/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 4.8461e-04 - val_loss: 0.0268
#
# Epoch 00034: val_loss did not improve from 0.01935
# Epoch 35/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 4.7999e-04 - val_loss: 0.0269
#
# Epoch 00035: val_loss did not improve from 0.01935
# Epoch 36/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 4.6531e-04 - val_loss: 0.0271
#
# Epoch 00036: val_loss did not improve from 0.01935
# Epoch 37/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 4.4285e-04 - val_loss: 0.0267
#
# Epoch 00037: val_loss did not improve from 0.01935
# Epoch 38/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 4.4394e-04 - val_loss: 0.0270
#
# Epoch 00038: val_loss did not improve from 0.01935
# Epoch 39/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 4.3488e-04 - val_loss: 0.0264
#
# Epoch 00039: val_loss did not improve from 0.01935
# Epoch 40/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 4.2105e-04 - val_loss: 0.0267
#
# Epoch 00040: val_loss did not improve from 0.01935
# Epoch 41/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 4.2138e-04 - val_loss: 0.0261
#
# Epoch 00041: val_loss did not improve from 0.01935
# Epoch 42/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 4.1527e-04 - val_loss: 0.0269
#
# Epoch 00042: val_loss did not improve from 0.01935
# Epoch 43/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 4.0160e-04 - val_loss: 0.0272
#
# Epoch 00043: val_loss did not improve from 0.01935
# Epoch 44/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 3.9339e-04 - val_loss: 0.0269
#
# Epoch 00044: val_loss did not improve from 0.01935
# Epoch 45/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 3.7195e-04 - val_loss: 0.0266
#
# Epoch 00045: val_loss did not improve from 0.01935
# Epoch 46/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 3.7287e-04 - val_loss: 0.0273
#
# Epoch 00046: val_loss did not improve from 0.01935
# Epoch 47/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 3.7389e-04 - val_loss: 0.0265
#
# Epoch 00047: val_loss did not improve from 0.01935
# Epoch 48/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 3.6481e-04 - val_loss: 0.0271
#
# Epoch 00048: val_loss did not improve from 0.01935
# Epoch 49/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 3.8191e-04 - val_loss: 0.0271
#
# Epoch 00049: val_loss did not improve from 0.01935
# Epoch 50/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 3.6709e-04 - val_loss: 0.0271
#
# Epoch 00050: val_loss did not improve from 0.01935
# Epoch 51/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 3.4408e-04 - val_loss: 0.0270
#
# Epoch 00051: val_loss did not improve from 0.01935
# Epoch 52/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 3.5772e-04 - val_loss: 0.0266
#
# Epoch 00052: val_loss did not improve from 0.01935
# Epoch 53/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 3.4542e-04 - val_loss: 0.0265
#
# Epoch 00053: val_loss did not improve from 0.01935
# Epoch 54/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 3.3440e-04 - val_loss: 0.0270
#
# Epoch 00054: val_loss did not improve from 0.01935
# Epoch 55/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 3.2968e-04 - val_loss: 0.0263
#
# Epoch 00055: val_loss did not improve from 0.01935
# Epoch 56/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 3.2824e-04 - val_loss: 0.0263
#
# Epoch 00056: val_loss did not improve from 0.01935
# Epoch 57/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 3.3453e-04 - val_loss: 0.0265
#
# Epoch 00057: val_loss did not improve from 0.01935
# Epoch 58/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 3.2128e-04 - val_loss: 0.0268
#
# Epoch 00058: val_loss did not improve from 0.01935
# Epoch 59/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 3.2442e-04 - val_loss: 0.0266
#
# Epoch 00059: val_loss did not improve from 0.01935
# Epoch 60/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 3.1563e-04 - val_loss: 0.0270
#
# Epoch 00060: val_loss did not improve from 0.01935
# Epoch 61/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 3.1203e-04 - val_loss: 0.0266
#
# Epoch 00061: val_loss did not improve from 0.01935
# Epoch 62/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 3.2220e-04 - val_loss: 0.0273
#
# Epoch 00062: val_loss did not improve from 0.01935
# Epoch 63/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 3.2340e-04 - val_loss: 0.0266
#
# Epoch 00063: val_loss did not improve from 0.01935
# Epoch 64/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 3.2913e-04 - val_loss: 0.0269
#
# Epoch 00064: val_loss did not improve from 0.01935
# Epoch 65/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 3.0635e-04 - val_loss: 0.0269
#
# Epoch 00065: val_loss did not improve from 0.01935
# Epoch 66/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 2.9672e-04 - val_loss: 0.0264
#
# Epoch 00066: val_loss did not improve from 0.01935
# Epoch 67/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 2.9891e-04 - val_loss: 0.0269
#
# Epoch 00067: val_loss did not improve from 0.01935
# Epoch 68/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 2.9010e-04 - val_loss: 0.0264
#
# Epoch 00068: val_loss did not improve from 0.01935
# Epoch 69/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 2.9613e-04 - val_loss: 0.0268
#
# Epoch 00069: val_loss did not improve from 0.01935
# Epoch 70/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 2.9009e-04 - val_loss: 0.0273
#
# Epoch 00070: val_loss did not improve from 0.01935
# Epoch 71/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 2.9196e-04 - val_loss: 0.0269
#
# Epoch 00071: val_loss did not improve from 0.01935
# Epoch 72/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 2.7748e-04 - val_loss: 0.0268
#
# Epoch 00072: val_loss did not improve from 0.01935
# Epoch 73/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 2.7608e-04 - val_loss: 0.0269
#
# Epoch 00073: val_loss did not improve from 0.01935
# Epoch 74/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 2.7221e-04 - val_loss: 0.0267
#
# Epoch 00074: val_loss did not improve from 0.01935
# Epoch 75/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 2.8338e-04 - val_loss: 0.0270
#
# Epoch 00075: val_loss did not improve from 0.01935
# Epoch 76/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 2.8788e-04 - val_loss: 0.0274
#
# Epoch 00076: val_loss did not improve from 0.01935
# Epoch 77/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 2.8359e-04 - val_loss: 0.0273
#
# Epoch 00077: val_loss did not improve from 0.01935
# Epoch 78/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 2.7963e-04 - val_loss: 0.0273
#
# Epoch 00078: val_loss did not improve from 0.01935
# Epoch 79/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 2.6789e-04 - val_loss: 0.0263
#
# Epoch 00079: val_loss did not improve from 0.01935
# Epoch 80/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 2.6789e-04 - val_loss: 0.0270
#
# Epoch 00080: val_loss did not improve from 0.01935
# Epoch 81/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 2.6601e-04 - val_loss: 0.0270
#
# Epoch 00081: val_loss did not improve from 0.01935
# Epoch 82/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 2.6783e-04 - val_loss: 0.0269
#
# Epoch 00082: val_loss did not improve from 0.01935
# Epoch 83/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 2.6453e-04 - val_loss: 0.0266
#
# Epoch 00083: val_loss did not improve from 0.01935
# Epoch 84/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 2.5235e-04 - val_loss: 0.0269
#
# Epoch 00084: val_loss did not improve from 0.01935
# Epoch 85/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 2.6209e-04 - val_loss: 0.0270
#
# Epoch 00085: val_loss did not improve from 0.01935
# Epoch 86/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 2.5470e-04 - val_loss: 0.0267
#
# Epoch 00086: val_loss did not improve from 0.01935
# Epoch 87/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 2.5213e-04 - val_loss: 0.0267
#
# Epoch 00087: val_loss did not improve from 0.01935
# Epoch 88/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 2.5267e-04 - val_loss: 0.0271
#
# Epoch 00088: val_loss did not improve from 0.01935
# Epoch 89/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 2.4944e-04 - val_loss: 0.0261
#
# Epoch 00089: val_loss did not improve from 0.01935
# Epoch 90/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 2.5131e-04 - val_loss: 0.0262
#
# Epoch 00090: val_loss did not improve from 0.01935
# Epoch 91/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 2.4296e-04 - val_loss: 0.0268
#
# Epoch 00091: val_loss did not improve from 0.01935
# Epoch 92/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 2.6325e-04 - val_loss: 0.0268
#
# Epoch 00092: val_loss did not improve from 0.01935
# Epoch 93/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 0.0054 - val_loss: 0.0239
#
# Epoch 00093: val_loss did not improve from 0.01935
# Epoch 94/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 0.0058 - val_loss: 0.0315
#
# Epoch 00094: val_loss did not improve from 0.01935
# Epoch 95/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 0.0039 - val_loss: 0.0269
#
# Epoch 00095: val_loss did not improve from 0.01935
# Epoch 96/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 0.0023 - val_loss: 0.0282
#
# Epoch 00096: val_loss did not improve from 0.01935
# Epoch 97/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 0.0014 - val_loss: 0.0280
#
# Epoch 00097: val_loss did not improve from 0.01935
# Epoch 98/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 0.0011 - val_loss: 0.0288
#
# Epoch 00098: val_loss did not improve from 0.01935
# Epoch 99/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 9.4572e-04 - val_loss: 0.0294
#
# Epoch 00099: val_loss did not improve from 0.01935
# Epoch 100/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 7.3371e-04 - val_loss: 0.0303
#
# Epoch 00100: val_loss did not improve from 0.01935
# Epoch 101/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 6.8842e-04 - val_loss: 0.0281
#
# Epoch 00101: val_loss did not improve from 0.01935
# Epoch 102/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 5.3667e-04 - val_loss: 0.0294
#
# Epoch 00102: val_loss did not improve from 0.01935
# Epoch 103/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 4.8140e-04 - val_loss: 0.0288
#
# Epoch 00103: val_loss did not improve from 0.01935
# Epoch 104/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 4.4647e-04 - val_loss: 0.0282
#
# Epoch 00104: val_loss did not improve from 0.01935
# Epoch 105/150
# 1712/1712 [==============================] - 0s 246us/step - loss: 4.2124e-04 - val_loss: 0.0286
#
# Epoch 00105: val_loss did not improve from 0.01935
# Epoch 106/150
# 1712/1712 [==============================] - 0s 231us/step - loss: 3.9798e-04 - val_loss: 0.0285
#
# Epoch 00106: val_loss did not improve from 0.01935
# Epoch 107/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 4.0671e-04 - val_loss: 0.0282
#
# Epoch 00107: val_loss did not improve from 0.01935
# Epoch 108/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 4.0073e-04 - val_loss: 0.0282
#
# Epoch 00108: val_loss did not improve from 0.01935
# Epoch 109/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 3.8275e-04 - val_loss: 0.0287
#
# Epoch 00109: val_loss did not improve from 0.01935
# Epoch 110/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 4.0408e-04 - val_loss: 0.0282
#
# Epoch 00110: val_loss did not improve from 0.01935
# Epoch 111/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 3.6507e-04 - val_loss: 0.0280
#
# Epoch 00111: val_loss did not improve from 0.01935
# Epoch 112/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 3.4976e-04 - val_loss: 0.0282
#
# Epoch 00112: val_loss did not improve from 0.01935
# Epoch 113/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 3.7345e-04 - val_loss: 0.0284
#
# Epoch 00113: val_loss did not improve from 0.01935
# Epoch 114/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 3.6701e-04 - val_loss: 0.0278
#
# Epoch 00114: val_loss did not improve from 0.01935
# Epoch 115/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 3.3854e-04 - val_loss: 0.0275
#
# Epoch 00115: val_loss did not improve from 0.01935
# Epoch 116/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 3.3231e-04 - val_loss: 0.0280
#
# Epoch 00116: val_loss did not improve from 0.01935
# Epoch 117/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 3.2374e-04 - val_loss: 0.0278
#
# Epoch 00117: val_loss did not improve from 0.01935
# Epoch 118/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 3.3872e-04 - val_loss: 0.0276
#
# Epoch 00118: val_loss did not improve from 0.01935
# Epoch 119/150
# 1712/1712 [==============================] - 0s 230us/step - loss: 3.0682e-04 - val_loss: 0.0281
#
# Epoch 00119: val_loss did not improve from 0.01935
# Epoch 120/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 3.1242e-04 - val_loss: 0.0275
#
# Epoch 00120: val_loss did not improve from 0.01935
# Epoch 121/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 3.0361e-04 - val_loss: 0.0282
#
# Epoch 00121: val_loss did not improve from 0.01935
# Epoch 122/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 3.0439e-04 - val_loss: 0.0280
#
# Epoch 00122: val_loss did not improve from 0.01935
# Epoch 123/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 3.4170e-04 - val_loss: 0.0277
#
# Epoch 00123: val_loss did not improve from 0.01935
# Epoch 124/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 3.1349e-04 - val_loss: 0.0275
#
# Epoch 00124: val_loss did not improve from 0.01935
# Epoch 125/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 3.1157e-04 - val_loss: 0.0275
#
# Epoch 00125: val_loss did not improve from 0.01935
# Epoch 126/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 2.8766e-04 - val_loss: 0.0278
#
# Epoch 00126: val_loss did not improve from 0.01935
# Epoch 127/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 2.8672e-04 - val_loss: 0.0274
#
# Epoch 00127: val_loss did not improve from 0.01935
# Epoch 128/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 2.9415e-04 - val_loss: 0.0271
#
# Epoch 00128: val_loss did not improve from 0.01935
# Epoch 129/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 2.8237e-04 - val_loss: 0.0275
#
# Epoch 00129: val_loss did not improve from 0.01935
# Epoch 130/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 2.8171e-04 - val_loss: 0.0277
#
# Epoch 00130: val_loss did not improve from 0.01935
# Epoch 131/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 2.9735e-04 - val_loss: 0.0270
#
# Epoch 00131: val_loss did not improve from 0.01935
# Epoch 132/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 2.7783e-04 - val_loss: 0.0271
#
# Epoch 00132: val_loss did not improve from 0.01935
# Epoch 133/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 3.0298e-04 - val_loss: 0.0274
#
# Epoch 00133: val_loss did not improve from 0.01935
# Epoch 134/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 2.7419e-04 - val_loss: 0.0276
#
# Epoch 00134: val_loss did not improve from 0.01935
# Epoch 135/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 2.7461e-04 - val_loss: 0.0274
#
# Epoch 00135: val_loss did not improve from 0.01935
# Epoch 136/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 2.6388e-04 - val_loss: 0.0273
#
# Epoch 00136: val_loss did not improve from 0.01935
# Epoch 137/150
# 1712/1712 [==============================] - 0s 235us/step - loss: 2.6411e-04 - val_loss: 0.0270
#
# Epoch 00137: val_loss did not improve from 0.01935
# Epoch 138/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 2.6421e-04 - val_loss: 0.0273
#
# Epoch 00138: val_loss did not improve from 0.01935
# Epoch 139/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 2.7186e-04 - val_loss: 0.0270
#
# Epoch 00139: val_loss did not improve from 0.01935
# Epoch 140/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 2.7392e-04 - val_loss: 0.0267
#
# Epoch 00140: val_loss did not improve from 0.01935
# Epoch 141/150
# 1712/1712 [==============================] - 0s 240us/step - loss: 2.8235e-04 - val_loss: 0.0268
#
# Epoch 00141: val_loss did not improve from 0.01935
# Epoch 142/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 2.7217e-04 - val_loss: 0.0271
#
# Epoch 00142: val_loss did not improve from 0.01935
# Epoch 143/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 2.6737e-04 - val_loss: 0.0270
#
# Epoch 00143: val_loss did not improve from 0.01935
# Epoch 144/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 2.5675e-04 - val_loss: 0.0268
#
# Epoch 00144: val_loss did not improve from 0.01935
# Epoch 145/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 2.4686e-04 - val_loss: 0.0271
#
# Epoch 00145: val_loss did not improve from 0.01935
# Epoch 146/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 2.5150e-04 - val_loss: 0.0274
#
# Epoch 00146: val_loss did not improve from 0.01935
# Epoch 147/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 2.5964e-04 - val_loss: 0.0273
#
# Epoch 00147: val_loss did not improve from 0.01935
# Epoch 148/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 2.5307e-04 - val_loss: 0.0273
#
# Epoch 00148: val_loss did not improve from 0.01935
# Epoch 149/150
# 1712/1712 [==============================] - 0s 233us/step - loss: 2.5403e-04 - val_loss: 0.0266
#
# Epoch 00149: val_loss did not improve from 0.01935
# Epoch 150/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 2.5111e-04 - val_loss: 0.0276
#
# Epoch 00150: val_loss did not improve from 0.01935

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))
